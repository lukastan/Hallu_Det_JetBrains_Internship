# %%
import numpy as np

# %%
data_path = "../data/raw/text8"
with open(data_path, 'r') as f:
    raw_data = f.read().split()

# %%
len(raw_data)
# Out:
# 17005207

# %%
raw_data[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
# %store raw_data
del raw_data
# Out:
# Stored 'raw_data' (list)
